# %%
# !pip install konlpy

# %%
# 메밀꽃.txt에서 나온 횟수가 5번이상인 단어 출력
from konlpy.tag import Kkma
from collections import Counter
infile = open("메밀꽃.txt", encoding='utf-8')
data=infile.read()

kkma = Kkma()
words=kkma.morphs(data)

vocab=Counter(words)
print(vocab)
vo=[print(f'-vlaue {k} apppears multiple times ({v} times)') for k,v in 
 vocab.items() if v > 4]
del vo[:1]
# Out:
# Counter({'.': 233, '이': 169, '었': 140, '다': 132, '는': 128, '"': 112, '을': 111, '하': 110, 'ㄴ': 107, '에': 102, '은': 96, '고': 89, '어': 65, '지': 60, '도': 60, '가': 50, '를': 44, ',': 40, 'ㄹ': 39, '있': 38, '의': 38, '들': 34, '게': 32, '것': 31, '아': 27, '나': 27, '으나': 25, '않': 25, '생원': 25, '없': 23, '았': 23, '허': 20, '기': 20, '수': 20, '보': 19, '되': 19, '동이': 19, '그': 18, '어서': 17, '?': 16, '야': 16, '때': 16, '생각': 15, '에서': 15, '로': 15, '나귀': 15, '만': 14, '장': 13, '네': 13, '두': 13, '꼴': 13, '물': 13, '이나': 12, '였': 12, '과': 12, '계집': 12, '말': 12, '면': 12, '며': 11, '겠': 11, '으로': 10, '달': 10, '밤': 10, '더': 10, '시작': 10, '같이': 10, '……': 10, '니': 10, '짐승': 10, '까지': 9, '조선': 9, '봉': 9, '소리': 9, '서': 9, 'ㄴ다': 9, '그렇': 9, '녀석': 9, '뒤': 8, '스럽': 8, '어야': 8, '걷': 8, '같': 8, '벌써': 7, '사람': 7, '일': 7, '집': 7, '구': 7, '세': 7, '부터': 7, '젖': 7, '속': 7, '아이': 7, '제천': 7, '지금': 7, '이야기': 7, '장판': 6, '요': 6, 'ㄴ지': 6, '내': 6, '길': 6, '버리': 6, '치': 6, '하나': 6, '젊': 6, '러': 6, '눈': 6, '울': 6, '라고': 6, '다고': 6, '평
# ...

# %%
# 소나기.txt에서 나온 횟수가 5번이상인 단어 출력
from konlpy.tag import Kkma
from collections import Counter
infile = open("소나기.txt", encoding='utf-8')
data=infile.read()

kkma = Kkma()
words=kkma.morphs(data)

vocab=Counter(words)
print(vocab)
vo=[print(f'-vlaue {k} apppears multiple times ({v} times)') for k,v in 
 vocab.items() if v > 4]
del vo[:1]
# Out:
# Counter({'.': 311, '다': 226, '었': 168, '이': 137, ',': 119, '을': 106, '"': 106, '가': 96, '어': 94, '는': 86, 'ㄴ': 78, '하': 77, '소녀': 72, '은': 71, '에': 70, '를': 54, '있': 54, '고': 54, '소년': 49, '아': 45, 'ㄴ다': 43, '았': 41, '지': 38, '것': 35, '의': 35, '도': 32, '으로': 27, '게': 26, '보': 25, '나': 25, '그러': 23, '한': 22, '않': 22, '에서': 20, 'ㄹ': 20, '더': 17, '로': 16, '같': 16, '?': 16, '기': 15, '속': 15, '며': 15, '날': 14, '저': 14, '그': 14, '꽃': 14, '서': 13, '생각': 13, '되': 13, '……': 13, '물': 12, '만': 12, '말': 12, "'": 12, '오': 12, '손': 11, '네': 10, '앉': 10, '듣': 10, '모르': 9, '전': 9, '어서': 9, '니': 9, '개울가': 8, '알': 8, '수': 8, '길': 8, '얼굴': 8, '내': 8, '하나': 8, '고는': 8, '달리': 8, '안': 8, '없': 8, '이것': 8, '참': 8, '돌아오': 7, '데': 7, '이번': 7, '그리': 7, '바보': 7, '갈꽃': 7, '뵈': 7, '집': 7, '들': 7, '비': 7, '개울': 6, '듯이': 6, '까지': 6, '더니': 6, '징검다리': 6, '나오': 6, '는지': 6, '다가': 6, '머리': 6, '일': 6, '잡': 6, '두': 6, '소리': 6, '못': 6, '자기': 6, '눈': 6, '산': 6, '허수아비': 6, '곳': 6, '밑': 6, '송아지': 6, '이사': 6, '호두': 6, '윤': 5, 
# ...

# %%
# 메밀꽃.txt에서 불용어를 제거하고 나온 횟수가 5번이상인 단어 출력
from konlpy.tag import Kkma
from collections import Counter
infile = open("메밀꽃.txt", encoding='utf-8')
data=infile.read()
stopfile = open("불용어.txt", encoding='utf-8')
stopwords = stopfile.read()

kkma = Kkma()
words=kkma.morphs(data)
stopwords=kkma.morphs(stopwords)

result=[]
for w in words:
  if w not in stopwords:
    result.append(w)


vocab=Counter(result)
print(vocab)
vo=[print(f'-vlaue {k} apppears multiple times ({v} times)') for k,v in 
 vocab.items() if v > 4]
del vo[:1]
# Out:
# Counter({'으나': 25, '생원': 25, '동이': 19, '나귀': 15, '장': 13, '꼴': 13, '이나': 12, '계집': 12, '달': 10, '밤': 10, '시작': 10, '짐승': 10, '조선': 9, '봉': 9, '소리': 9, '녀석': 9, '뒤': 8, '스럽': 8, '걷': 8, '벌써': 7, '세': 7, '젖': 7, '제천': 7, '이야기': 7, '장판': 6, 'ㄴ지': 6, '길': 6, '버리': 6, '치': 6, '젊': 6, '눈': 6, '울': 6, '라고': 6, '다고': 6, '평': 6, '처녀': 6, '죠': 6, '이란': 5, '축': 5, '군': 5, '을까': 5, '대화': 5, '달이': 5, '듯이': 5, '충줏집': 5, '란': 5, '어머니': 5, '장난': 4, '각다귀': 4, '왼손잡이': 4, '그만': 4, '한번': 4, '눈치': 4, '자리': 4, '걱정': 4, '없이': 4, '아비': 4, '가슴': 4, '흘리': 4, '쫓': 4, '입': 4, '몸': 4, '늘': 4, '읍내': 4, '단': 4, '고개': 4, '듣': 4, '벗': 4, '새끼': 4, 'ㄴ가': 4, '아직': 3, '벌이': 3, '패': 3, '법': 3, '기어코': 3, 'ㄹ까': 3, '오늘': 3, '렷다': 3, '물건': 3, '꼭': 3, '터지': 3, '웃': 3, '후리': 3, '부': 3, '더니': 3, '얼굴': 3, '떨리': 3, '만나': 3, '제법': 3, '피': 3, '술': 3, '돌': 3, '돌아다니': 3, '무어': 3, '나가': 3, '해지': 3, '넘': 3, '낳': 3, '당나귀': 3, '야단': 3, '에요': 3, '반평생': 3, '달빛': 3, '주인': 3, '번': 3, '땀': 3, '모양': 3, '놀': 3, '채찍': 3, '당하': 3, '다가': 3, '처음': 
# ...

# %%
# 소나기.txt에서 불용어를 제거하고 나온 횟수가 5번이상인 단어 출력
from konlpy.tag import Kkma
from collections import Counter
infile = open("소나기.txt", encoding='utf-8')
data=infile.read()
stopfile = open("불용어.txt", encoding='utf-8')
stopwords = stopfile.read()

kkma = Kkma()
words=kkma.morphs(data)
stopwords=kkma.morphs(stopwords)

result=[]
for w in words:
  if w not in stopwords:
    result.append(w)


vocab=Counter(result)
print(vocab)
vo=[print(f'-vlaue {k} apppears multiple times ({v} times)') for k,v in 
 vocab.items() if v > 4]
del vo[:1]
# Out:
# Counter({'소녀': 72, '소년': 49, '날': 14, '꽃': 14, '손': 11, '앉': 10, '듣': 10, '개울가': 8, '길': 8, '얼굴': 8, '고는': 8, '돌아오': 7, '바보': 7, '갈꽃': 7, '뵈': 7, '개울': 6, '듯이': 6, '더니': 6, '징검다리': 6, '는지': 6, '다가': 6, '머리': 6, '잡': 6, '소리': 6, '못': 6, '눈': 6, '산': 6, '허수아비': 6, '밑': 6, '송아지': 6, '이사': 6, '호두': 6, '윤': 5, '초시': 5, '오늘': 5, '버리': 5, '움키': 5, '건너': 5, '조약돌': 5, '갈밭': 5, '가을': 5, '다고': 5, '덜': 5, '주머니': 5, '번': 5, '느냐': 5, '없이': 5, '멀': 5, '달려가': 5, 'ㄴ다는': 5, '수숫단': 5, '아버지': 5, '물장난': 4, '서울': 4, '학교': 4, '둑': 4, '스웨터': 4, '그냥': 4, '그대로': 4, '들어서': 4, '지나': 4, 'ㄹ라': 4, '몸': 4, '시작': 4, '스럽': 4, '거기': 4, '맛': 4, '먹': 4, '꺾': 4, '많이': 4, '새': 4, '갈': 4, '며칠': 3, '째': 3, '가운데': 3, '비키': 3, '지나가': 3, '세수': 3, '분홍': 3, '희': 3, '자꾸': 3, '일어': 3, '뛰': 3, '뒤': 3, '햇살': 3, '그리고': 3, 'ㄴ지': 3, '내리': 3, '가슴': 3, '자리': 3, '놀': 3, '입술': 3, '체': 3, '갈림길': 3, '가깝': 3, '흔들': 3, '돌아가': 3, '보조개': 3, '쪽빛': 3, '하늘': 3, '저놈': 3, '독수리': 3, '밭': 3, '원두막': 3, '참외': 3, '아직': 3, '향하': 3, '고르': 3, '칡덩굴': 3, '달': 
# ...
